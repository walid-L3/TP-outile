# %%
s=input('saisir une chaine de caractair;');
l=s[::-1];
print('la chaine invers:',l);
# Out:
# saisir une chaine de caractair;0123456789
# la chaine invers: 9876543210

# %%
print('Choisissez un nombre de 1 à 3 (ou zéro pour terminer) :')
a = int(input()) # input() permet de saisir une chaine de caractres au clavier - int(input()) convertit la saisie en entier
# on aurait pu écrire a = int(input(Choisissez un nombre de 1 à 3 (ou zéro pour terminer) :')) 
while a != 0:           # l'opérateur != signifie "différent de"
    if a == 1:
        print("Vous avez choisi un!")
    elif a == 2:
        print("Vous préférez le deux!")
    elif a == 3:
        print("Vous optez pour le plus grand des trois!")
    else :
        print("Un nombre entre UN et TROIS, s.v.p.!!")
    a = int(input('Choisissez un nombre de 1 à 3 (ou zéro pour terminer) : '))
print("Vous avez entré zéro!")
print("L'exercice est donc terminé.")
# Out:
# Choisissez un nombre de 1 à 3 (ou zéro pour terminer) :
# 1
# Vous avez choisi un!
# Choisissez un nombre de 1 à 3 (ou zéro pour terminer) : 2
# Vous préférez le deux!
# Choisissez un nombre de 1 à 3 (ou zéro pour terminer) : 3
# Vous optez pour le plus grand des trois!
# Choisissez un nombre de 1 à 3 (ou zéro pour terminer) : 0
# Vous avez entré zéro!
# L'exercice est donc terminé.

# %%
note=[];
a=input('donner la not:',);
a= int(a);
s=0;
s=int(s);
while   a >=  0:
    note.append(a);
    print(note)
    p=len(note);
    print('le nombre des notes saisie est:',p);
    mx=max(note);
    print('la bonne note est:',mx);
    mn=min(note)
    print('la mauvaise note est:',mn); 
    p=int(p);   
    s=s+a;  
    print('la moyen est:',s/p);  
    a=input('donner la not:',);
    a=int(a);        
    if a<0 :
        print('erreur verifier voutre not');
# Out:
# donner la not:4
# [4]
# le nombre des notes saisie est: 1
# la bonne note est: 4
# la mauvaise note est: 4
# la moyen est: 4.0
# donner la not:3
# [4, 3]
# le nombre des notes saisie est: 2
# la bonne note est: 4
# la mauvaise note est: 3
# la moyen est: 3.5
# donner la not:7
# [4, 3, 7]
# le nombre des notes saisie est: 3
# la bonne note est: 7
# la mauvaise note est: 3
# la moyen est: 4.666666666666667
# donner la not:9
# [4, 3, 7, 9]
# le nombre des notes saisie est: 4
# la bonne note est: 9
# la mauvaise note est: 3
# la moyen est: 5.75
# donner la not:0
# [4, 3, 7, 9, 0]
# le nombre des notes saisie est: 5
# la bonne note est: 9
# la mauvaise note est: 0
# la moyen est: 4.6
# donner la not:-4
# erreur verifier voutre not

# %%
def function ():
    n=10
    while n>0:
        print( n/2 , n%2)
        n=n-1

# %%
function()
# Out:
# 5.0 0
# 4.5 1
# 4.0 0
# 3.5 1
# 3.0 0
# 2.5 1
# 2.0 0
# 1.5 1
# 1.0 0
# 0.5 1

# %%
def function2 ():
    print ('Affichage du resultat et du reste de la division des entiers de 10')
    function ()

# %%
function2()
# Out:
# Affichage du resultat et du reste de la division des entiers de 10
# 5.0 0
# 4.5 1
# 4.0 0
# 3.5 1
# 3.0 0
# 2.5 1
# 2.0 0
# 1.5 1
# 1.0 0
# 0.5 1

# %%
def function(n):
    while n>0:
        print(n/2,n%2)
        n=n-1

# %%
function(1000)
# Out:
# 500.0 0
# 499.5 1
# 499.0 0
# 498.5 1
# 498.0 0
# 497.5 1
# 497.0 0
# 496.5 1
# 496.0 0
# 495.5 1
# 495.0 0
# 494.5 1
# 494.0 0
# 493.5 1
# 493.0 0
# 492.5 1
# 492.0 0
# 491.5 1
# 491.0 0
# 490.5 1
# 490.0 0
# 489.5 1
# 489.0 0
# 488.5 1
# 488.0 0
# 487.5 1
# 487.0 0
# 486.5 1
# 486.0 0
# 485.5 1
# 485.0 0
# 484.5 1
# 484.0 0
# 483.5 1
# 483.0 0
# 482.5 1
# 482.0 0
# 481.5 1
# 481.0 0
# 480.5 1
# 480.0 0
# 479.5 1
# 479.0 0
# 478.5 1
# 478.0 0
# 477.5 1
# 477.0 0
# 476.5 1
# 476.0 0
# 475.5 1
# 475.0 0
# 474.5 1
# 474.0 0
# 473.5 1
# 473.0 0
# 472.5 1
# 472.0 0
# 471.5 1
# 471.0 0
# 470.5 1
# 470.0 0
# 469.5 1
# 469.0 0
# 468.5 1
# 468.0 0
# 467.5 1
# 467.0 0
# 466.5 1
# 466.0 0
# 465.5 1
# 465.0 0
# 464.5 1
# 464.0 0
# 463.5 1
# 463.0 0
# 462.5 1
# 462.0 0
# 461.5 1
# 461.0 0
# 460.5 1
# 460.0 0
# 459.5 1
# 459.0 0
# 458.5 1
# 458.0 0
# 457.5 1
# 457.0 0
# 456.5 1
# 456.0 0
# 455.5 1
# 455.0 0
# 454.5 1
# 454.0 0
# 453.5 1
# 453.0 0
# 452.5 1
# 452.0 0
# 451.5 1
# 451.0 0
# 450.5 1
# ...

# %%
def function(entree,diviseur):
    while entree>0:
        print(entree/diviseur,entree%diviseur)
        entree=entree-1

# %%
function(500,10)
# Out:
# 50.0 0
# 49.9 9
# 49.8 8
# 49.7 7
# 49.6 6
# 49.5 5
# 49.4 4
# 49.3 3
# 49.2 2
# 49.1 1
# 49.0 0
# 48.9 9
# 48.8 8
# 48.7 7
# 48.6 6
# 48.5 5
# 48.4 4
# 48.3 3
# 48.2 2
# 48.1 1
# 48.0 0
# 47.9 9
# 47.8 8
# 47.7 7
# 47.6 6
# 47.5 5
# 47.4 4
# 47.3 3
# 47.2 2
# 47.1 1
# 47.0 0
# 46.9 9
# 46.8 8
# 46.7 7
# 46.6 6
# 46.5 5
# 46.4 4
# 46.3 3
# 46.2 2
# 46.1 1
# 46.0 0
# 45.9 9
# 45.8 8
# 45.7 7
# 45.6 6
# 45.5 5
# 45.4 4
# 45.3 3
# 45.2 2
# 45.1 1
# 45.0 0
# 44.9 9
# 44.8 8
# 44.7 7
# 44.6 6
# 44.5 5
# 44.4 4
# 44.3 3
# 44.2 2
# 44.1 1
# 44.0 0
# 43.9 9
# 43.8 8
# 43.7 7
# 43.6 6
# 43.5 5
# 43.4 4
# 43.3 3
# 43.2 2
# 43.1 1
# 43.0 0
# 42.9 9
# 42.8 8
# 42.7 7
# 42.6 6
# 42.5 5
# 42.4 4
# 42.3 3
# 42.2 2
# 42.1 1
# 42.0 0
# 41.9 9
# 41.8 8
# 41.7 7
# 41.6 6
# 41.5 5
# 41.4 4
# 41.3 3
# 41.2 2
# 41.1 1
# 41.0 0
# 40.9 9
# 40.8 8
# 40.7 7
# 40.6 6
# 40.5 5
# 40.4 4
# 40.3 3
# 40.2 2
# 40.1 1
# 40.0 0
# 39.9 9
# 39.8 8
# 39.7 7
# 39.6 6
# 39.5 5
# 39.4 4
# 39.3 3
# 39.2 2
# 39.1 1
# 39.0 0
# ...

# %%
def afficher3fois ( arg ):
    print (arg,arg,arg )

# %%
afficher3fois('qsdfqsgf')
# Out:
# qsdfqsgf qsdfqsgf qsdfqsgf

# %%
afficher3fois(654654)
# Out:
# 654654 654654 654654

# %%
afficher3fois(4*12)
# Out:
# 48 48 48

# %%
afficher3fois([1,2,3])
# Out:
# [1, 2, 3] [1, 2, 3] [1, 2, 3]

# %%
def function (entree =10,diviseur =2):
    while (entree >0):
        print(entree/diviseur,entree%diviseur)
        entree = entree -1

# %%
function(5,3)
# Out:
# 1.6666666666666667 2
# 1.3333333333333333 1
# 1.0 0
# 0.6666666666666666 2
# 0.3333333333333333 1

# %%
function(entree=10,diviseur=3)
# Out:
# 3.3333333333333335 1
# 3.0 0
# 2.6666666666666665 2
# 2.3333333333333335 1
# 2.0 0
# 1.6666666666666667 2
# 1.3333333333333333 1
# 1.0 0
# 0.6666666666666666 2
# 0.3333333333333333 1

# %%
def multiplication(n,p):
    return n*p

# %%
print(multiplication(4,15))
# Out:
# 60

# %%
a=multiplication(11,2)

# %%
a
# Out:
# 22

# %%
def fonction_test (* args ):
    print ( " type de args:",type(args))
    for arg in args :
        print ( "parametre:",arg)
print()

# %%
fonction_test(1,"ad")
# Out:
#  type de args: <class 'tuple'>
# parametre: 1
# parametre: ad

# %%
def somme (*n):
    p=len(n);
    s=0;
    s=int(s);
    p=int(p);
    i=0;
    i=int(i);
    while i < p :
        s=s+n[i]
        i=i+1;
    print(s)

# %%
somme(4,5)
# Out:
# 9
